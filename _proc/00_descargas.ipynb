# %% [raw]
# ---
# description: "Funciones para descargar, procesar y actualizar las fuentes de datos\
#   \ que se usan en la librer\xEDa."
# output-file: descargas.html
# title: descargas
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## descarga_denue
#
# Esta función descarga diferentes bases preprocesadas del DENUE. En general el procesamiento involucra integrar los sectores en una base única y homogeneizar los nombres de los campos.
#
# La función admite un parámetro que controla cuál base se descarga, toma en cuenta que la base completa es MUY grande.

# %%
#|output: asis
#| echo: false
show_doc(descarga_denue)
# Out:
# ---
#
# [source](https://github.com/CentroGeo/pyLandUseMX/blob/master/pyLandUseMX/descargas.py#L20){target="_blank" style="float:right; font-size:smaller"}
#
# ### descarga_denue
#
# >      descarga_denue (tipo:str='zmvm_2022')
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | tipo | str | zmvm_2022 | Qué archivo vamos a descargar: ejemplo, zmvm_2022, zmvm_full, mexico_2022, mexico_full |
# | **Returns** | **None** |  |  |

# %%
pth = descarga_denue()
pth = descarga_denue('ejemplo')
pth
# Out:
# El archivo ya está descargado
# El archivo ya está descargado
# '/home/plablo/git/pyLandUseMX/datos/descargas/ejemplo_denue.gpkg'

# %% [markdown]
# ## descarga_redes
#
# Esta función descarga un Geopackage con la red de transporte importada de [OpenStreetMap](https://www.openstreetmap.org/#map=5/23.944/-102.579).
#
# **Nota:** En este momento la red sólo está disponible para la Zona Metropolitana de la Ciudad de México.

# %%
#|output: asis
#| echo: false
show_doc(descarga_redes)
# Out:
# ---
#
# [source](https://github.com/CentroGeo/pyLandUseMX/blob/master/pyLandUseMX/descargas.py#L44){target="_blank" style="float:right; font-size:smaller"}
#
# ### descarga_redes
#
# >      descarga_redes ()

# %%
pth = descarga_redes()
pth
# Out:
# El archivo ya está descargado
# '/home/plablo/git/pyLandUseMX/datos/descargas/red_zmvm.gpkg'

# %% [markdown]
# ## descarga_poligonos_ciudades
#
# Esta función descarga las slhuetas de las 100 ciudades más grandes de México (SUN, 2016)

# %%
#|output: asis
#| echo: false
show_doc(descarga_poligonos_ciudades)
# Out:
# ---
#
# [source](https://github.com/CentroGeo/pyLandUseMX/blob/master/pyLandUseMX/descargas.py#L57){target="_blank" style="float:right; font-size:smaller"}
#
# ### descarga_poligonos_ciudades
#
# >      descarga_poligonos_ciudades ()

# %%
pth = descarga_poligonos_ciudades()
pth
# Out:
# El archivo ya está descargado
# '/home/plablo/git/pyLandUseMX/datos/descargas/silhuetas.shp.zip'

# %% [markdown]
# ## descarga_colonias_cdmx

# %%
#|output: asis
#| echo: false
show_doc(descarga_colonias_cdmx)
# Out:
# ---
#
# [source](https://github.com/CentroGeo/pyLandUseMX/blob/master/pyLandUseMX/descargas.py#L70){target="_blank" style="float:right; font-size:smaller"}
#
# ### descarga_colonias_cdmx
#
# >      descarga_colonias_cdmx ()

# %%
pth = descarga_colonias_cdmx()
pth
# Out:
# '/home/plablo/git/pyLandUseMX/datos/descargas/colonias_cdmx.zip'

# %% [markdown]
# ## descarga_datos_completos
#
# Esta función llama a todas las anmteriores para descargar todos los datos.

# %%
#|output: asis
#| echo: false
show_doc(descarga_datos_completos)
# Out:
# ---
#
# [source](https://github.com/CentroGeo/pyLandUseMX/blob/master/pyLandUseMX/descargas.py#L83){target="_blank" style="float:right; font-size:smaller"}
#
# ### descarga_datos_completos
#
# >      descarga_datos_completos ()

# %% [markdown]
# descarga_datos_completos()
